# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1

len(chipo)
# Out:
# 4622

# %%
# Solution 2

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo.groupby('item_name').count().sort_values(by=['order_id'],ascending=False)
# Out:
#                                        order_id  quantity  choice_description  \
# item_name
# Chicken Bowl                                726       726                 726
# Chicken Burrito                             553       553                 553
# Chips and Guacamole                         479       479                   0
# Steak Burrito                               368       368                 368
# Canned Soft Drink                           301       301                 301
# Steak Bowl                                  211       211                 211
# Chips                                       211       211                   0
# Bottled Water                               162       162                   0
# Chicken Soft Tacos                          115       115                 115
# Chicken Salad Bowl                          110       110                 110
# Chips and Fresh Tomato Salsa                110       110                   0
# Canned Soda                                 104       104                 104
# Side of Chips                               101       101                   0
# Veggie Burrito                               95        95                  95
# Barbacoa Burrito                             91        91                  91
# Veggie Bowl                                  85        85                  85
# Carnitas Bowl                                68        68                  68
# Barbacoa Bowl                                66        66                  66
# Carnitas Burrito                             59        59                  59
# Steak Soft Tacos                             55        55                  55
# 6 Pack Soft Drink                            54        54                  54
# Chips and Tomatillo Red Chili Salsa          48        48                   0
# Chicken Crispy Tacos                         47        47                  47
# Chips and Tomatillo Green Chili Salsa        43        43                   0
# Carnitas Soft Tacos                          40        40                  40
# Steak Crispy Tacos                           35        35                  35
# Chips and Tomatillo-Green Chili Salsa        31        31                   0
# Steak Salad Bowl                             29        29                  29
# Nantucket Nectar                             27        27                  27
# Barbacoa Soft Tacos                          25        25                  25
# Chips and Roasted Chili Corn Salsa           22        22                   0
# Chips and Tomatillo-Red Chili Salsa          20        20                   0
# Izze                                         20        20                  20
# Veggie Salad Bowl                            18        18                  18
# Chips and Roasted Chili-Corn Salsa           18        18                   0
# Barbacoa Crispy Tacos                        11        11                  11
# Barbacoa Salad Bowl                          10        10                  10
# Chicken Salad                                 9         9                   9
# Carnitas Crispy Tacos                         7         7                   7
# Veggie Soft Tacos                             7         7                   7
# Burrito                                       6         6                   6
# Veggie Salad                                  6         6                   6
# Carnitas Salad Bowl                           6         6                   6
# Steak Salad                                   4         4                   4
# Bowl                                          2         2                   2
# Salad                                         2         2                   2
# Crispy Tacos                                  2         2                   2
# Chips and Mild Fresh Tomato Salsa             1         1                   0
# Carnitas Salad                                1         1                   1
# Veggie Crispy Tacos                           1         1                   1
#
#                                        item_price
# item_name
# Chicken Bowl                                  726
# Chicken Burrito                               553
# Chips and Guacamole                           479
# Steak Burrito                                 368
# Canned Soft Drink                             301
# Steak Bowl                                    211
# Chips                                         211
# Bottled Water                                 162
# Chicken Soft Tacos                            115
# Chicken Salad Bowl                            110
# Chips and Fresh Tomato Salsa                  110
# Canned Soda                                   104
# Side of Chips                                 101
# Veggie Burrito                                 95
# Barbacoa Burrito                               91
# Veggie Bowl                                    85
# Carnitas Bowl                                  68
# Barbacoa Bowl                                  66
# Carnitas Burrito                               59
# Steak Soft Tacos                               55
# 6 Pack Soft Drink                              54
# Chips and Tomatillo Red Chili Salsa            48
# Chicken Crispy Tacos                           47
# Chips and Tomatillo Green Chili Salsa          43
# Carnitas Soft Tacos                            40
# Steak Crispy Tacos                             35
# Chips and Tomatillo-Green Chili Salsa          31
# Steak Salad Bowl                               29
# Nantucket Nectar                               27
# Barbacoa Soft Tacos                            25
# Chips and Roasted Chili Corn Salsa             22
# Chips and Tomatillo-Red Chili Salsa            20
# Izze                                           20
# Veggie Salad Bowl                              18
# Chips and Roasted Chili-Corn Salsa             18
# Barbacoa Crispy Tacos                          11
# Barbacoa Salad Bowl                            10
# Chicken Salad                                   9
# Carnitas Crispy Tacos                           7
# Veggie Soft Tacos                               7
# Burrito                                         6
# Veggie Salad                                    6
# Carnitas Salad Bowl                             6
# Steak Salad                                     4
# Bowl                                            2
# Salad                                           2
# Crispy Tacos                                    2
# Chips and Mild Fresh Tomato Salsa               1
# Carnitas Salad                                  1
# Veggie Crispy Tacos                             1

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo.groupby('item_name').get_group('Chicken Bowl').sum()
# Out:
# order_id                                                         713926
# quantity                                                            761
# item_name             Chicken BowlChicken BowlChicken BowlChicken Bo...
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price            $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 ...
# dtype: object

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.groupby('choice_description').sum().sort_values(by=['order_id'],ascending=False)
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     37550        40
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42
# [Lemonade]                                             31892        36
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream,...     29614        30
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]      27583        30
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     24637        25
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice,...     24432        36
# [Fresh Tomato Salsa, [Fajita Vegetables, Rice, ...     24051        20
# [Nestea]                                               23349        20
# [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]          23326        26
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     23031        21
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]       22664        24
# [Fresh Tomato Salsa, [Fajita Vegetables, Rice, ...     22117        19
# [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]        21848        22
# [Fresh Tomato Salsa, [Fajita Vegetables, Rice, ...     21722        21
# [Roasted Chili Corn Salsa, [Rice, Black Beans, ...     20902        21
# [Fresh Tomato Salsa, [Cheese, Lettuce]]                20662        18
# [Coca Cola]                                            19282        32
# [Fresh Tomato Salsa, [Fajita Vegetables, Rice, ...     17989        19
# [Tomatillo Red Chili Salsa, [Rice, Cheese, Sour...     17854        20
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     17529        23
# [Fresh Tomato Salsa, Rice]                             17175        22
# [Tomatillo Red Chili Salsa, [Rice, Cheese, Lett...     15512        20
# [Tomatillo Red Chili Salsa, [Rice, Black Beans,...     15244        18
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream,...     14903        12
# [Roasted Chili Corn Salsa, [Rice, Black Beans, ...     14823        15
# ...                                                      ...       ...
# [Tomatillo-Green Chili Salsa (Medium), [Rice, F...        81         1
# [Tomatillo-Green Chili Salsa (Medium), Lettuce]           78         1
# [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomato...        76         1
# [Tomatillo Red Chili Salsa, [Rice, Black Beans,...        75         1
# [Roasted Chili Corn Salsa (Medium), [Pinto Bean...        74         1
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-...        73         1
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-...        72         1
# [Tomatillo-Green Chili Salsa (Medium), [Rice, B...        66         1
# [Roasted Chili Corn Salsa, [Rice, Fajita Vegeta...        65         1
# [Roasted Chili Corn Salsa, [Rice, Pinto Beans, ...        57         1
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-...        52         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...        51         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...        51         1
# [Tomatillo-Red Chili Salsa (Hot), [Black Beans,...        51         2
# [Fresh Tomato Salsa (Mild), [Black Beans, Rice,...        46         1
# [Tomatillo Red Chili Salsa, [Rice, Fajita Veget...        44         1
# [Roasted Chili Corn Salsa, [Sour Cream, Guacamo...        41         1
# [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans,...        38         1
# [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese]]         30         1
# [Fresh Tomato Salsa, [Fajita Vegetables, Black ...        26         1
# [Roasted Chili Corn Salsa, Rice]                          18         1
# [[Roasted Chili Corn Salsa (Medium), Fresh Toma...        16         1
# [[Tomatillo-Green Chili Salsa (Medium), Roasted...        14         1
# [Roasted Chili Corn Salsa (Medium), [Pinto Bean...        13         1
# [[Tomatillo-Green Chili Salsa (Medium), Tomatil...        12         1
# [[Fresh Tomato Salsa (Mild), Tomatillo-Green Ch...        11         1
# [Tomatillo Red Chili Salsa, [Fajita Vegetables,...        10         1
# [Tomatillo-Green Chili Salsa (Medium), [Pinto B...         8         1
# [Tomatillo Red Chili Salsa, [Fajita Vegetables,...         4         1
# [Tomatillo Green Chili Salsa, [Pinto Beans, Che...         4         1
#
# [1043 rows x 2 columns]

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo['item_price'] = list(map(lambda x: float(x[1:]),chipo['item_price']))

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.6+ KB

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# #### Step 13.c. Check the item price type

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %% [markdown]
# ### Step 16. What is the average amount per order?

# %%
# Solution 1

# %%
# Solution 2

# %% [markdown]
# ### Step 17. How many different items are sold?
